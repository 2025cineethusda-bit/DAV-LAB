# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\neeth\Downloads\archive\student_exam_performance.csv")
df.head()
# Out:
#    student_id  age  gender education_level school_type family_income  \
# 0  STU_000001   20  Female     High School      Public        Middle
# 1  STU_000002   17    Male     High School      Public        Middle
# 2  STU_000003   18   Other   Undergraduate      Public        Middle
# 3  STU_000004   20    Male     High School      Public        Middle
# 4  STU_000005   16  Female     High School     Private          High
#
#   parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 0              NaN       Rural                78.36          2.95  ...
# 1              NaN    Suburban                73.40          2.89  ...
# 2           Master       Urban                82.76          3.35  ...
# 3      High School    Suburban                60.61          2.57  ...
# 4         Bachelor    Suburban                74.79          2.84  ...
#
#    exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df.head()
# Out:
#    student_id  age  gender education_level school_type family_income  \
# 0  STU_000001   20  Female     High School      Public        Middle
# 1  STU_000002   17    Male     High School      Public        Middle
# 2  STU_000003   18   Other   Undergraduate      Public        Middle
# 3  STU_000004   20    Male     High School      Public        Middle
# 4  STU_000005   16  Female     High School     Private          High
#
#   parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 0              NaN       Rural                78.36          2.95  ...
# 1              NaN    Suburban                73.40          2.89  ...
# 2           Master       Urban                82.76          3.35  ...
# 3      High School    Suburban                60.61          2.57  ...
# 4         Bachelor    Suburban                74.79          2.84  ...
#
#    exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df.tail()
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 99995  STU_099996   17    Male   Undergraduate      Public  Upper-Middle
# 99996  STU_099997   14  Female     High School      Public  Upper-Middle
# 99997  STU_099998   16  Female     High School      Public  Upper-Middle
# 99998  STU_099999   15  Female     High School     Private          High
# 99999  STU_100000   18  Female   Undergraduate     Charter  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 99995              NaN    Suburban                78.73           NaN  ...
# 99996         Bachelor    Suburban                75.70          2.98  ...
# 99997      High School    Suburban                84.69          3.27  ...
# 99998           Master       Rural                74.70          3.06  ...
# 99999              NaN       Urban                76.73          2.97  ...
#
#        exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df.shape
# Out:
# (100000, 44)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'education_level', 'school_type',
#        'family_income', 'parent_education', 'urban_rural',
#        'previous_exam_score', 'previous_gpa', 'attendance_percentage',
#        'assignment_completion_rate', 'class_participation',
#        'study_hours_per_day', 'self_study_hours', 'private_tuition',
#        'online_learning_hours', 'study_consistency', 'study_environment',
#        'study_method', 'revision_frequency', 'practice_tests_completed',
#        'notes_quality', 'sleep_hours', 'sleep_quality', 'daily_screen_time',
#        'physical_activity_hours', 'break_frequency', 'stress_level',
#        'motivation_level', 'internet_access', 'device_availability',
#        'educational_app_usage', 'online_course_hours', 'exam_difficulty',
#        'exam_preparation_days', 'questions_attempted', 'questions_correct',
#        'time_management_score', 'exam_anxiety_level', 'exam_score',
# ...

# %%
df.dtypes
# Out:
# student_id                        str
# age                             int64
# gender                            str
# education_level                   str
# school_type                       str
# family_income                     str
# parent_education                  str
# urban_rural                       str
# previous_exam_score           float64
# previous_gpa                  float64
# attendance_percentage         float64
# assignment_completion_rate    float64
# class_participation               str
# study_hours_per_day           float64
# self_study_hours              float64
# private_tuition                 int64
# online_learning_hours         float64
# study_consistency                 str
# study_environment                 str
# study_method                      str
# revision_frequency                str
# practice_tests_completed        int64
# notes_quality                     str
# sleep_hours                   float64
# sleep_quality                     str
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   student_id                  100000 non-null  str
#  1   age                         100000 non-null  int64
#  2   gender                      100000 non-null  str
#  3   education_level             100000 non-null  str
#  4   school_type                 100000 non-null  str
#  5   family_income               100000 non-null  str
#  6   parent_education            93474 non-null   str
#  7   urban_rural                 100000 non-null  str
#  8   previous_exam_score         100000 non-null  float64
#  9   previous_gpa                92207 non-null   float64
#  10  attendance_percentage       90137 non-null   float64
#  11  assignment_completion_rate  100000 non-null  float64
#  12  class_participation         100000 non-null  str
# ...

# %%
df.describe()
# Out:
#                  age  previous_exam_score  previous_gpa  \
# count  100000.000000        100000.000000  92207.000000
# mean       17.005740            69.531033      2.780892
# std         1.999562            11.379108      0.478218
# min        14.000000            30.000000      1.000000
# 25%        15.000000            61.820000      2.460000
# 50%        17.000000            69.530000      2.780000
# 75%        19.000000            77.232500      3.110000
# max        20.000000           100.000000      4.000000
#
#        attendance_percentage  assignment_completion_rate  study_hours_per_day  \
# count           90137.000000               100000.000000        100000.000000
# mean               84.616882                   69.724405             2.995725
# std                 7.922485                   12.127179             1.719466
# min                46.340000                   20.000000             0.500000
# ...

# %%
df["age"].mean()
# Out:
# np.float64(17.00574)

# %%
df["age"].median()
# Out:
# np.float64(17.0)

# %%
df["age"].mode
# Out:
# <bound method Series.mode of 0        20
# 1        17
# 2        18
# 3        20
# 4        16
#          ..
# 99995    17
# 99996    14
# 99997    16
# 99998    15
# 99999    18
# Name: age, Length: 100000, dtype: int64>

# %%
df["age"].var()
# Out:
# np.float64(3.9982470348703485)

# %%
df["age"].std()
# Out:
# np.float64(1.999561710693208)

# %%
df["age"].min()
# Out:
# np.int64(14)

# %%
df["age"].max()
# Out:
# np.int64(20)

# %%
df["age"].count()
# Out:
# np.int64(100000)

# %%
df.isnull()
# Out:
#        student_id    age  gender  education_level  school_type  family_income  \
# 0           False  False   False            False        False          False
# 1           False  False   False            False        False          False
# 2           False  False   False            False        False          False
# 3           False  False   False            False        False          False
# 4           False  False   False            False        False          False
# ...           ...    ...     ...              ...          ...            ...
# 99995       False  False   False            False        False          False
# 99996       False  False   False            False        False          False
# 99997       False  False   False            False        False          False
# 99998       False  False   False            False        False          False
# 99999       False  False   False            False        False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# education_level                  0
# school_type                      0
# family_income                    0
# parent_education              6526
# urban_rural                      0
# previous_exam_score              0
# previous_gpa                  7793
# attendance_percentage         9863
# assignment_completion_rate       0
# class_participation              0
# study_hours_per_day              0
# self_study_hours                 0
# private_tuition                  0
# online_learning_hours            0
# study_consistency                0
# study_environment                0
# study_method                     0
# revision_frequency               0
# practice_tests_completed         0
# notes_quality                 8407
# sleep_hours                      0
# sleep_quality                 6994
# daily_screen_time                0
# physical_activity_hours          0
# ...

# %%
df.isnull().mean()*100
# Out:
# student_id                    0.000
# age                           0.000
# gender                        0.000
# education_level               0.000
# school_type                   0.000
# family_income                 0.000
# parent_education              6.526
# urban_rural                   0.000
# previous_exam_score           0.000
# previous_gpa                  7.793
# attendance_percentage         9.863
# assignment_completion_rate    0.000
# class_participation           0.000
# study_hours_per_day           0.000
# self_study_hours              0.000
# private_tuition               0.000
# online_learning_hours         0.000
# study_consistency             0.000
# study_environment             0.000
# study_method                  0.000
# revision_frequency            0.000
# practice_tests_completed      0.000
# notes_quality                 8.407
# sleep_hours                   0.000
# sleep_quality                 6.994
# daily_screen_time             0.000
# ...

# %%
df.dropna()
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 2      STU_000003   18   Other   Undergraduate      Public        Middle
# 3      STU_000004   20    Male     High School      Public        Middle
# 4      STU_000005   16  Female     High School     Private          High
# 7      STU_000008   20  Female   Undergraduate     Private  Lower-Middle
# 8      STU_000009   15    Male   Undergraduate      Public  Lower-Middle
# ...           ...  ...     ...             ...         ...           ...
# 99991  STU_099992   19  Female   Undergraduate      Public  Upper-Middle
# 99992  STU_099993   19  Female     High School      Public           Low
# 99994  STU_099995   15    Male     High School      Public           Low
# 99997  STU_099998   16  Female     High School      Public  Upper-Middle
# 99998  STU_099999   15  Female     High School     Private          High
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# ...

# %%
df.fillna(0)
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 0      STU_000001   20  Female     High School      Public        Middle
# 1      STU_000002   17    Male     High School      Public        Middle
# 2      STU_000003   18   Other   Undergraduate      Public        Middle
# 3      STU_000004   20    Male     High School      Public        Middle
# 4      STU_000005   16  Female     High School     Private          High
# ...           ...  ...     ...             ...         ...           ...
# 99995  STU_099996   17    Male   Undergraduate      Public  Upper-Middle
# 99996  STU_099997   14  Female     High School      Public  Upper-Middle
# 99997  STU_099998   16  Female     High School      Public  Upper-Middle
# 99998  STU_099999   15  Female     High School     Private          High
# 99999  STU_100000   18  Female   Undergraduate     Charter  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# ...

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of        student_id  age  gender education_level school_type family_income  \
# 0      STU_000001   20  Female     High School      Public        Middle
# 1      STU_000002   17    Male     High School      Public        Middle
# 2      STU_000003   18   Other   Undergraduate      Public        Middle
# 3      STU_000004   20    Male     High School      Public        Middle
# 4      STU_000005   16  Female     High School     Private          High
# ...           ...  ...     ...             ...         ...           ...
# 99995  STU_099996   17    Male   Undergraduate      Public  Upper-Middle
# 99996  STU_099997   14  Female     High School      Public  Upper-Middle
# 99997  STU_099998   16  Female     High School      Public  Upper-Middle
# 99998  STU_099999   15  Female     High School     Private          High
# 99999  STU_100000   18  Female   Undergraduate     Charter  Lower-Middle
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 0      STU_000001   20  Female     High School      Public        Middle
# 1      STU_000002   17    Male     High School      Public        Middle
# 2      STU_000003   18   Other   Undergraduate      Public        Middle
# 3      STU_000004   20    Male     High School      Public        Middle
# 4      STU_000005   16  Female     High School     Private          High
# ...           ...  ...     ...             ...         ...           ...
# 99995  STU_099996   17    Male   Undergraduate      Public  Upper-Middle
# 99996  STU_099997   14  Female     High School      Public  Upper-Middle
# 99997  STU_099998   16  Female     High School      Public  Upper-Middle
# 99998  STU_099999   15  Female     High School     Private          High
# 99999  STU_100000   18  Female   Undergraduate     Charter  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# ...

# %%
df["age"]
# Out:
# 0        20
# 1        17
# 2        18
# 3        20
# 4        16
#          ..
# 99995    17
# 99996    14
# 99997    16
# 99998    15
# 99999    18
# Name: age, Length: 100000, dtype: int64

# %%
df.iloc[0:5]
# Out:
#    student_id  age  gender education_level school_type family_income  \
# 0  STU_000001   20  Female     High School      Public        Middle
# 1  STU_000002   17    Male     High School      Public        Middle
# 2  STU_000003   18   Other   Undergraduate      Public        Middle
# 3  STU_000004   20    Male     High School      Public        Middle
# 4  STU_000005   16  Female     High School     Private          High
#
#   parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 0              NaN       Rural                78.36          2.95  ...
# 1              NaN    Suburban                73.40          2.89  ...
# 2           Master       Urban                82.76          3.35  ...
# 3      High School    Suburban                60.61          2.57  ...
# 4         Bachelor    Suburban                74.79          2.84  ...
#
#    exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df[["age","exam_score"]]
# Out:
#        age  exam_score
# 0       20       90.40
# 1       17       86.21
# 2       18       76.11
# 3       20       79.74
# 4       16       50.66
# ...    ...         ...
# 99995   17       66.46
# 99996   14       96.54
# 99997   16       74.66
# 99998   15       85.85
# 99999   18       54.40
#
# [100000 rows x 2 columns]

# %%
df[df["age"] > 30]
# Out:
# Empty DataFrame
# Columns: [student_id, age, gender, education_level, school_type, family_income, parent_education, urban_rural, previous_exam_score, previous_gpa, attendance_percentage, assignment_completion_rate, class_participation, study_hours_per_day, self_study_hours, private_tuition, online_learning_hours, study_consistency, study_environment, study_method, revision_frequency, practice_tests_completed, notes_quality, sleep_hours, sleep_quality, daily_screen_time, physical_activity_hours, break_frequency, stress_level, motivation_level, internet_access, device_availability, educational_app_usage, online_course_hours, exam_difficulty, exam_preparation_days, questions_attempted, questions_correct, time_management_score, exam_anxiety_level, exam_score, performance_grade, pass_status, performance_level]
# Index: []
#
# [0 rows x 44 columns]

# %%
df.sort_values("age")
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 58     STU_000059   14    Male   Undergraduate     Private  Lower-Middle
# 63     STU_000064   14  Female   Undergraduate      Public  Lower-Middle
# 71314  STU_071315   14  Female   Undergraduate      Public  Lower-Middle
# 71323  STU_071324   14    Male   Undergraduate      Public        Middle
# 71324  STU_071325   14    Male     High School     Private        Middle
# ...           ...  ...     ...             ...         ...           ...
# 71341  STU_071342   20    Male   Undergraduate     Private        Middle
# 71340  STU_071341   20    Male     High School     Private          High
# 46     STU_000047   20  Female     High School      Public        Middle
# 71321  STU_071322   20  Female   Undergraduate      Public           Low
# 71338  STU_071339   20  Female   Undergraduate     Private  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# ...

# %%
df.rename(columns={"age":"age_Years"})
# Out:
#        student_id  age_Years  gender education_level school_type  \
# 0      STU_000001         20  Female     High School      Public
# 1      STU_000002         17    Male     High School      Public
# 2      STU_000003         18   Other   Undergraduate      Public
# 3      STU_000004         20    Male     High School      Public
# 4      STU_000005         16  Female     High School     Private
# ...           ...        ...     ...             ...         ...
# 99995  STU_099996         17    Male   Undergraduate      Public
# 99996  STU_099997         14  Female     High School      Public
# 99997  STU_099998         16  Female     High School      Public
# 99998  STU_099999         15  Female     High School     Private
# 99999  STU_100000         18  Female   Undergraduate     Charter
#
#       family_income parent_education urban_rural  previous_exam_score  \
# 0            Middle              NaN       Rural                78.36
# ...

# %%
df.drop("Bonus", axis=1)
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 0      STU_000001   20  Female     High School      Public        Middle
# 1      STU_000002   17    Male     High School      Public        Middle
# 2      STU_000003   18   Other   Undergraduate      Public        Middle
# 3      STU_000004   20    Male     High School      Public        Middle
# 4      STU_000005   16  Female     High School     Private          High
# ...           ...  ...     ...             ...         ...           ...
# 99995  STU_099996   17    Male   Undergraduate      Public  Upper-Middle
# 99996  STU_099997   14  Female     High School      Public  Upper-Middle
# 99997  STU_099998   16  Female     High School      Public  Upper-Middle
# 99998  STU_099999   15  Female     High School     Private          High
# 99999  STU_100000   18  Female   Undergraduate     Charter  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# ...
